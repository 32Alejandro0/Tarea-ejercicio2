# %%
frase = input ("Introduce una serie de caracteres:")
veces = int (input("Introduce el numero entero de veces que quieres que se repita"))
for i in range (veces):
  print (frase)
# Out:
# Introduce una serie de caracteres:abc
# Introduce el numero entero de veces que quieres que se repita10
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
